# %% [markdown]
# # Лабораторная работа №1

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 
sns.set(style="ticks")

# %%
data = pd.read_csv('data/boston_house_prices.csv', sep=",")

# %%
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
data.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# B       -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# LSTAT    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
# MEDV    -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.695360 -0.376955
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT      MEDV
# CRIM    -0.379670  0.625505  0.582764  0.289946 -0.385064  0.455621 -0.388305
# ZN       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# INDUS   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# CHAS    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# NOX     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# RM       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.613808  0.695360
# AGE     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955
# DIS      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929
# RAD     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# TAX     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# PTRATIO -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# B        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# LSTAT   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# MEDV     0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %%
del data['AGE']
del data['DIS']
del data['B']

# %%
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM  RAD  TAX  PTRATIO  LSTAT  MEDV
# 0  0.00632  18.0   2.31     0  0.538  6.575    1  296     15.3   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  6.421    2  242     17.8   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  7.185    2  242     17.8   4.03  34.7
# 3  0.03237   0.0   2.18     0  0.458  6.998    3  222     18.7   2.94  33.4
# 4  0.06905   0.0   2.18     0  0.458  7.147    3  222     18.7   5.33  36.2

# %%
data.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       RAD  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.625505
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.311948
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.595129
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251 -0.007368
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.611441
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.209847
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  1.000000
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.910228
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.464741
# LSTAT    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.488676
# MEDV    -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.695360 -0.381626
#
#               TAX   PTRATIO     LSTAT      MEDV
# CRIM     0.582764  0.289946  0.455621 -0.388305
# ZN      -0.314563 -0.391679 -0.412995  0.360445
# INDUS    0.720760  0.383248  0.603800 -0.483725
# CHAS    -0.035587 -0.121515 -0.053929  0.175260
# NOX      0.668023  0.188933  0.590879 -0.427321
# RM      -0.292048 -0.355501 -0.613808  0.695360
# RAD      0.910228  0.464741  0.488676 -0.381626
# TAX      1.000000  0.460853  0.543993 -0.468536
# PTRATIO  0.460853  1.000000  0.374044 -0.507787
# LSTAT    0.543993  0.374044  1.000000 -0.737663
# MEDV    -0.468536 -0.507787 -0.737663  1.000000

# %%
del data['RAD']

# %%
data.corr()
# Out:
#              CRIM        ZN     INDUS       NOX        RM       TAX   PTRATIO  \
# CRIM     1.000000 -0.200469  0.406583  0.420972 -0.219247  0.582764  0.289946
# ZN      -0.200469  1.000000 -0.533828 -0.516604  0.311991 -0.314563 -0.391679
# INDUS    0.406583 -0.533828  1.000000  0.763651 -0.391676  0.720760  0.383248
# NOX      0.420972 -0.516604  0.763651  1.000000 -0.302188  0.668023  0.188933
# RM      -0.219247  0.311991 -0.391676 -0.302188  1.000000 -0.292048 -0.355501
# TAX      0.582764 -0.314563  0.720760  0.668023 -0.292048  1.000000  0.460853
# PTRATIO  0.289946 -0.391679  0.383248  0.188933 -0.355501  0.460853  1.000000
# LSTAT    0.455621 -0.412995  0.603800  0.590879 -0.613808  0.543993  0.374044
# MEDV    -0.388305  0.360445 -0.483725 -0.427321  0.695360 -0.468536 -0.507787
#
#             LSTAT      MEDV
# CRIM     0.455621 -0.388305
# ZN      -0.412995  0.360445
# INDUS    0.603800 -0.483725
# NOX      0.590879 -0.427321
# RM      -0.613808  0.695360
# TAX      0.543993 -0.468536
# PTRATIO  0.374044 -0.507787
# LSTAT    1.000000 -0.737663
# MEDV    -0.737663  1.000000

# %%
sns.heatmap(data.corr(), annot=True, fmt='.1f')

# %%
fig, ax = plt.subplots(figsize = (10, 10))
sns.scatterplot(ax = ax, x = 'MEDV', y = 'RM', data = data)

# %%
fig, ax = plt.subplots(figsize = (10, 10))
sns.scatterplot(ax = ax, x = 'MEDV', y = 'LSTAT', data = data)

# %%
fig, ax = plt.subplots(figsize = (10, 10))
sns.scatterplot(ax = ax, x = 'MEDV', y = 'INDUS', data = data)
